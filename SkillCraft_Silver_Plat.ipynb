# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

print("numpy version:", np.__version__)
print("tensorflow version:", tf.__version__)
print("pandas version:", pd.__version__)
# Out:
# numpy version: 1.13.3
# tensorflow version: 1.4.0
# pandas version: 0.19.2

# %% [markdown]
# See original notebook SkillCraft_Experiment1_Rank_with_GM for details.

# %%
skillcraft = pd.read_csv('SkillCraft1_Dataset.csv')
sc = skillcraft.query('LeagueIndex == 2 | LeagueIndex == 4')

# %%
data = sc.iloc[:, 5:]
data = data.values

target = sc.iloc[:, 1]
target = target.values

# reassign labels for two-class
posClass = 2
negClass = 4
dataIndx = (target==posClass) + (target==negClass)
data = data[dataIndx]
target = target[dataIndx]#.reshape(-1, 1)
target[target==posClass] = 1
target[target==negClass] = 0

#np.random.seed(45689)
rnd_idx = np.arange(np.shape(data)[0])
np.random.shuffle(rnd_idx)

# trBatch = int(np.ceil(0.8*len(rnd_idx)))
# validBatch = int(np.ceil(0.1*len(rnd_idx)))
#trBatch = int(np.ceil(0.7*len(rnd_idx)))
trBatch = 1040

trainData, testData = (data[rnd_idx[0:trBatch],:],
                       data[rnd_idx[trBatch:],:])

trainTarget, testTarget = (target[rnd_idx[0:trBatch]],
                           target[rnd_idx[trBatch:]])

# %%
print("trainData shape:", trainData.shape)
print("trainTarget shape:", trainTarget.shape)
print("testData shape:", testData.shape)
print("testTarget shape:", testTarget.shape)
# Out:
# trainData shape: (1040, 15)
# trainTarget shape: (1040,)
# testData shape: (118, 15)
# testTarget shape: (118,)

# %%
print(trainData.dtype)
print(trainTarget.dtype)
print(np.unique(trainTarget))
print(np.unique(testTarget))
print(np.bincount(trainTarget))
print(np.bincount(testTarget))
# Out:
# float64
# int64
# [0 1]
# [0 1]
# [739 301]
# [72 46]

# %%
# need to expand the targets (currently just a scalar) into a one-hot 10-D vector
# code from https://stackoverflow.com/a/42874726/8346497
classes = np.unique(trainTarget).shape[0]
trainTarget = np.eye(classes)[trainTarget]
testTarget = np.eye(classes)[testTarget]

print("new trainTarget shape:", trainTarget.shape)
print("new testTarget shape:", testTarget.shape)
# Out:
# new trainTarget shape: (1040, 2)
# new testTarget shape: (118, 2)

# %%
def build_layer(incoming, num_hidden_units):
    """
    incoming: the input tensor containing the hidden activations from previous layer
    num_hidden_units: the number of hidden units for this layer
    
    takes the hidden activations from the previous layer and then returns the weighted sum of
    the inputs for the current hidden layer (before passing through activation)
        
    also return the weights W_layer for regularization
    """
    # Xavier initialization
    num_input_units = incoming.get_shape().as_list()[1]
    variance = 3. / (num_input_units + num_hidden_units)
    
    W_layer = tf.Variable(tf.truncated_normal(shape=[num_input_units, num_hidden_units], stddev=tf.sqrt(variance)))
    b_layer = tf.Variable(tf.constant(0.0, shape=[num_hidden_units]))
    
    # the output of this hidden layer
    layer = tf.matmul(incoming, W_layer) + b_layer
    return layer, W_layer

# %%
def cross_validation(data, target, i, cv_index):
    """
    data:
    target:
    
    Returns two datasets (composed of data and labels) partitioned into size (i-1)*N/i and N/i.
    The split is made along cv_index (should be greater than 1)
    Precondition: i >= 3, 1 <= cv_index <= i-1
    """
    data_cv = np.split(data, i)
    target_cv = np.split(target, i)
    
    trainData = np.concatenate(data_cv[0:cv_index] + data_cv[cv_index+1:], axis=0)
    trainTarget = np.concatenate(target_cv[0:cv_index] + target_cv[cv_index+1:], axis=0)
    
    validData = data_cv[cv_index]
    validTarget = target_cv[cv_index]
    
    return trainData, trainTarget, validData, validTarget

# %% [markdown]
# ## Experiment 1: Fully connected neural network

# %%
X = tf.placeholder(tf.float32, shape=[None, trainData.shape[1]])
y_target = tf.placeholder(tf.float32, shape=[None, trainTarget.shape[1]])

# input to hidden layer
hidden_layer_in, W_layer1 = build_layer(X, 500)
keep_prob = tf.placeholder(tf.float32) # control dropout to activate during training only
hidden_layer_out = tf.nn.dropout(tf.nn.relu(hidden_layer_in), keep_prob)

# hidden layer to output
y_predicted, W_layer2 = build_layer(hidden_layer_out, trainTarget.shape[1])

# perform a softmax on the output layer
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_target, logits=y_predicted))

# add L2 norm penalty for every weight in the network
penalty = 3e-3
regularizers = tf.nn.l2_loss(W_layer1) + tf.nn.l2_loss(W_layer2)
cross_entropy += penalty * regularizers

# %%
global_step = tf.Variable(0, trainable=False)
eta_0 = 1e-3
eta = tf.train.exponential_decay(eta_0, global_step, 5000, 0.9, staircase=True)

optimizer = tf.train.AdamOptimizer(learning_rate=eta)
train = optimizer.minimize(cross_entropy, global_step=global_step)
y_class_predicted = tf.argmax(y_predicted, 1)
y_class_target = tf.argmax(y_target, 1)
errors = tf.reduce_sum(tf.cast(tf.not_equal(y_class_predicted, y_class_target), tf.float32))

# %%
batch_size=720

train_errors = []
valid_errors = []
train_xentropy_losses = []
valid_xentropy_losses = []

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    i=0
    
    split = 9
    
    for partition in range(0, split):
        trainDataCV, trainTargetCV, validData, validTarget = cross_validation(trainData, trainTarget, split, partition)
        
        for step in range(1, 101):
            if i >= trainData.shape[0]:
                i -= trainData.shape[0]
                train_error, train_loss = sess.run([errors, cross_entropy],
                                                    feed_dict={X: trainDataCV.take(indices, axis=0, mode='wrap'),
                                                               y_target: trainTargetCV.take(indices, axis=0, mode='wrap'),
                                                               keep_prob: 1.0})
                valid_error, valid_loss = sess.run([errors, cross_entropy],
                                                    feed_dict={X: validData, y_target: validTarget,
                                                               keep_prob: 1.0})
                train_xentropy_losses.append(train_loss)
                train_errors.append(train_error)
                valid_xentropy_losses.append(valid_loss)
                valid_errors.append(valid_error)

            indices = range(i, i+batch_size)
            _, loss = sess.run([train, cross_entropy], feed_dict={X: trainDataCV.take(indices, axis=0, mode='wrap'),
                                                                  y_target: trainTargetCV.take(indices, axis=0, mode='wrap'),
                                                                  keep_prob: 0.5})
            i += batch_size

            if (step % 20 == 0):
                train_error, train_loss = sess.run([errors, cross_entropy],
                                                    feed_dict={X: trainDataCV.take(indices, axis=0, mode='wrap'),
                                                               y_target: trainTargetCV.take(indices, axis=0, mode='wrap'),
                                                               keep_prob: 1.0})
                valid_error, valid_loss = sess.run([errors, cross_entropy],
                                                    feed_dict={X: validData, y_target: validTarget,
                                                               keep_prob: 1.0})
                print("Iter: %4d, xentropy-train: %4.6f, xentropy-valid: %4.6f, Train errs: %d, Valid errs: %d"%
                      (partition*100+step, train_loss, valid_loss, train_error, valid_error))
# Out:
# Iter:   20, xentropy-train: 1.769818, xentropy-valid: 1.497585, Train errs: 191, Valid errs: 21
# Iter:   40, xentropy-train: 1.375040, xentropy-valid: 1.256788, Train errs: 176, Valid errs: 22
# Iter:   60, xentropy-train: 1.042651, xentropy-valid: 0.975546, Train errs: 173, Valid errs: 22
# Iter:   80, xentropy-train: 0.806359, xentropy-valid: 0.763580, Train errs: 173, Valid errs: 22
# Iter:  100, xentropy-train: 0.706110, xentropy-valid: 0.693282, Train errs: 169, Valid errs: 23
# Iter:  120, xentropy-train: 0.599037, xentropy-valid: 0.862110, Train errs: 168, Valid errs: 27
# Iter:  140, xentropy-train: 0.558724, xentropy-valid: 0.802933, Train errs: 157, Valid errs: 27
# Iter:  160, xentropy-train: 0.503446, xentropy-valid: 0.692693, Train errs: 150, Valid errs: 27
# Iter:  180, xentropy-train: 0.498135, xentropy-valid: 0.686778, Train errs: 150, Valid errs: 28
# Iter:  200, xentropy-train: 0.482926, xentropy-valid: 0.658226, Train errs: 146, Valid errs: 28
# Iter:  220, xentropy-train: 0.487016, xentropy-valid: 0.493313, Train errs: 157, Valid errs: 20
# Iter:  240, xentropy-train: 0.481031, xentropy-valid: 0.501036, Train errs: 147, Valid errs: 20
# Iter:  260, xentropy-train: 0.477724, xentropy-valid: 0.515251, Train errs: 156, Valid errs: 20
# Iter:  280, xentropy-train: 0.473918, xentropy-valid: 0.511264, Train errs: 148, Valid errs: 20
# Iter:  300, xentropy-train: 0.470891, xentropy-valid: 0.506815, Train errs: 149, Valid errs: 20
# Iter:  320, xentropy-train: 0.466361, xentropy-valid: 0.521554, Train errs: 151, Valid errs: 20
# Iter:  340, xentropy-train: 0.463789, xentropy-valid: 0.524038, Train errs: 150, Valid errs: 19
# Iter:  360, xentropy-train: 0.460935, xentropy-valid: 0.531446, Train errs: 151, Valid errs: 21
# Iter:  380, xentropy-train: 0.458535, xentropy-valid: 0.535151, Train errs: 148, Valid errs: 21
# Iter:  400, xentropy-train: 0.455238, xentropy-valid: 0.534421, Train errs: 148, Valid errs: 22
# Iter:  420, xentropy-train: 0.460170, xentropy-valid: 0.499052, Train errs: 146, Valid errs: 22
# Iter:  440, xentropy-train: 0.459237, xentropy-valid: 0.504179, Train errs: 147, Valid errs: 22
# Iter:  460, xentropy-train: 0.458036, xentropy-valid: 0.498903, Train errs: 144, Valid errs: 21
# Iter:  480, xentropy-train: 0.456742, xentropy-valid: 0.504888, Train errs: 144, Valid errs: 22
# Iter:  500, xentropy-train: 0.455339, xentropy-valid: 0.503288, Train errs: 147, Valid errs: 23
# Iter:  520, xentropy-train: 0.462241, xentropy-valid: 0.436599, Train errs: 148, Valid errs: 14
# Iter:  540, xentropy-train: 0.462385, xentropy-valid: 0.441563, Train errs: 148, Valid errs: 17
# Iter:  560, xentropy-train: 0.460044, xentropy-valid: 0.447389, Train errs: 146, Valid errs: 15
# Iter:  580, xentropy-train: 0.458475, xentropy-valid: 0.450536, Train errs: 145, Valid errs: 16
# Iter:  600, xentropy-train: 0.457927, xentropy-valid: 0.454882, Train errs: 147, Valid errs: 15
# Iter:  620, xentropy-train: 0.452623, xentropy-valid: 0.495251, Train errs: 147, Valid errs: 21
# Iter:  640, xentropy-train: 0.452608, xentropy-valid: 0.499899, Train errs: 146, Valid errs: 22
# Iter:  660, xentropy-train: 0.450895, xentropy-valid: 0.496850, Train errs: 141, Valid errs: 20
# Iter:  680, xentropy-train: 0.449472, xentropy-valid: 0.499302, Train errs: 142, Valid errs: 21
# Iter:  700, xentropy-train: 0.448020, xentropy-valid: 0.498417, Train errs: 138, Valid errs: 22
# Iter:  720, xentropy-train: 0.452252, xentropy-valid: 0.459324, Train errs: 142, Valid errs: 19
# Iter:  740, xentropy-train: 0.449235, xentropy-valid: 0.468554, Train errs: 140, Valid errs: 18
# Iter:  760, xentropy-train: 0.448730, xentropy-valid: 0.471200, Train errs: 139, Valid errs: 19
# Iter:  780, xentropy-train: 0.447816, xentropy-valid: 0.474571, Train errs: 139, Valid errs: 20
# Iter:  800, xentropy-train: 0.446599, xentropy-valid: 0.479880, Train errs: 145, Valid errs: 20
# Iter:  820, xentropy-train: 0.456567, xentropy-valid: 0.387332, Train errs: 143, Valid errs: 12
# Iter:  840, xentropy-train: 0.456651, xentropy-valid: 0.385533, Train errs: 146, Valid errs: 13
# Iter:  860, xentropy-train: 0.454322, xentropy-valid: 0.389001, Train errs: 140, Valid errs: 13
# Iter:  880, xentropy-train: 0.454299, xentropy-valid: 0.391654, Train errs: 141, Valid errs: 13
# Iter:  900, xentropy-train: 0.453574, xentropy-valid: 0.396020, Train errs: 145, Valid errs: 13

# %%
# plot training curve for classification error vs number of epochs
plt.plot(train_errors, 'b-', label='training')
plt.plot(valid_errors, 'r-', label='validation')
plt.title('Classification Errors vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Errors')
plt.legend()

# %%
# plot training and validation for cross-entropy loss vs number of epochs
plt.plot(train_xentropy_losses, 'b-', label='training')
plt.plot(valid_xentropy_losses, 'r-', label='validation')
plt.title('Cross-entropy Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %% [markdown]
# One layer, 500 units, $\eta=0.001$, $\lambda=0.0003$, dropout rate $p=0.5$
#
# ### Result on test set

# %%
X = tf.placeholder(tf.float32, shape=[None, trainData.shape[1]])
y_target = tf.placeholder(tf.float32, shape=[None, trainTarget.shape[1]])

# input to hidden layer
hidden_layer_in, W_layer1 = build_layer(X, 500)
keep_prob = tf.placeholder(tf.float32) # control dropout to activate during training only
hidden_layer_out = tf.nn.dropout(tf.nn.relu(hidden_layer_in), keep_prob)

# hidden layer to output
y_predicted, W_layer2 = build_layer(hidden_layer_out, trainTarget.shape[1])

# perform a softmax on the output layer
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_target, logits=y_predicted))

# add L2 norm penalty for every weight in the network
penalty = 3e-4
regularizers = tf.nn.l2_loss(W_layer1) + tf.nn.l2_loss(W_layer2)
cross_entropy += penalty * regularizers

# %%
global_step = tf.Variable(0, trainable=False)
eta_0 = 1e-3
eta = tf.train.exponential_decay(eta_0, global_step, 5000, 0.9, staircase=True)

optimizer = tf.train.AdamOptimizer(learning_rate=eta)
train = optimizer.minimize(cross_entropy, global_step=global_step)
y_class_predicted = tf.argmax(y_predicted, 1)
y_class_target = tf.argmax(y_target, 1)
errors = tf.reduce_sum(tf.cast(tf.not_equal(y_class_predicted, y_class_target), tf.float32))
accuracy = tf.reduce_mean(tf.cast(tf.equal(y_class_predicted, y_class_target), tf.float32))

# %%
batch_size=256

train_accuracies = []
valid_accuracies = []
test_accuracies = []
train_errors = []
valid_errors = []
test_errors = []
train_xentropy_losses = []
valid_xentropy_losses = []
test_xentropy_losses = []

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    i=0
    
    split = 10
    
    for partition in range(0, split):
        trainDataCV, trainTargetCV, validData, validTarget = cross_validation(trainData, trainTarget, split, partition)
        
        for step in range(1, 101):
            if i >= trainData.shape[0]:
                i -= trainData.shape[0]
                train_acc, train_error, train_loss = sess.run([accuracy, errors, cross_entropy],
                                                               feed_dict={X: trainDataCV.take(indices, axis=0, mode='wrap'),
                                                                          y_target: trainTargetCV.take(indices, axis=0, mode='wrap'),
                                                                          keep_prob: 1.0})
                valid_acc, valid_error, valid_loss = sess.run([accuracy, errors, cross_entropy],
                                                               feed_dict={X: validData, y_target: validTarget,
                                                                          keep_prob: 1.0})
                test_acc, test_error, test_loss = sess.run([accuracy, errors, cross_entropy],
                                                            feed_dict={X: testData, y_target: testTarget,
                                                                       keep_prob: 1.0})
                train_xentropy_losses.append(train_loss)
                train_accuracies.append(train_acc)
                train_errors.append(train_error)
                
                valid_xentropy_losses.append(valid_loss)
                valid_accuracies.append(valid_acc)
                valid_errors.append(valid_error)
                
                test_xentropy_losses.append(test_loss)
                test_accuracies.append(test_acc)
                test_errors.append(test_error)

            indices = range(i, i+batch_size)
            _, loss = sess.run([train, cross_entropy], feed_dict={X: trainDataCV.take(indices, axis=0, mode='wrap'),
                                                                  y_target: trainTargetCV.take(indices, axis=0, mode='wrap'),
                                                                  keep_prob: 0.5})
            i += batch_size

            if (step % 20 == 0):
                train_error, train_loss = sess.run([errors, cross_entropy],
                                                    feed_dict={X: trainDataCV.take(indices, axis=0, mode='wrap'),
                                                               y_target: trainTargetCV.take(indices, axis=0, mode='wrap'),
                                                               keep_prob: 1.0})
                valid_error, valid_loss = sess.run([errors, cross_entropy],
                                                    feed_dict={X: validData, y_target: validTarget,
                                                               keep_prob: 1.0})
                test_error, test_loss = sess.run([errors, cross_entropy],
                                                  feed_dict={X: testData, y_target: testTarget,
                                                             keep_prob: 1.0})
                print("Iter: %4d, x-train: %4.5f, x-valid: %4.5f, x-test: %4.5f, Train errs: %d, Valid errs: %d, Test errs: %d"%
                      (partition*100+step, train_loss, valid_loss, test_loss, train_error, valid_error, test_error))
# Out:
# Iter:   20, x-train: 1.80977, x-valid: 1.62367, x-test: 2.01320, Train errs: 64, Valid errs: 24, Test errs: 26
# Iter:   40, x-train: 1.10031, x-valid: 0.94639, x-test: 1.13093, Train errs: 61, Valid errs: 26, Test errs: 31
# Iter:   60, x-train: 0.76213, x-valid: 0.70585, x-test: 0.81470, Train errs: 56, Valid errs: 26, Test errs: 26
# Iter:   80, x-train: 0.66936, x-valid: 0.59834, x-test: 0.68344, Train errs: 66, Valid errs: 27, Test errs: 30
# Iter:  100, x-train: 0.64475, x-valid: 0.52892, x-test: 0.57969, Train errs: 68, Valid errs: 26, Test errs: 31
# Iter:  120, x-train: 0.48605, x-valid: 0.52917, x-test: 0.53162, Train errs: 60, Valid errs: 26, Test errs: 32
# Iter:  140, x-train: 0.49792, x-valid: 0.53797, x-test: 0.54100, Train errs: 65, Valid errs: 28, Test errs: 29
# Iter:  160, x-train: 0.47476, x-valid: 0.52153, x-test: 0.51861, Train errs: 57, Valid errs: 28, Test errs: 30
# Iter:  180, x-train: 0.49220, x-valid: 0.51123, x-test: 0.50115, Train errs: 58, Valid errs: 27, Test errs: 29
# Iter:  200, x-train: 0.47464, x-valid: 0.51294, x-test: 0.49554, Train errs: 54, Valid errs: 25, Test errs: 28
# Iter:  220, x-train: 0.47997, x-valid: 0.54977, x-test: 0.49969, Train errs: 63, Valid errs: 24, Test errs: 28
# Iter:  240, x-train: 0.44476, x-valid: 0.54505, x-test: 0.49399, Train errs: 56, Valid errs: 25, Test errs: 27
# Iter:  260, x-train: 0.44187, x-valid: 0.54327, x-test: 0.49995, Train errs: 57, Valid errs: 25, Test errs: 28
# Iter:  280, x-train: 0.42371, x-valid: 0.54831, x-test: 0.49300, Train errs: 48, Valid errs: 28, Test errs: 27
# Iter:  300, x-train: 0.45586, x-valid: 0.54192, x-test: 0.49881, Train errs: 46, Valid errs: 25, Test errs: 30
# Iter:  320, x-train: 0.46268, x-valid: 0.45743, x-test: 0.50257, Train errs: 51, Valid errs: 18, Test errs: 28
# Iter:  340, x-train: 0.47637, x-valid: 0.45489, x-test: 0.49272, Train errs: 55, Valid errs: 19, Test errs: 27
# Iter:  360, x-train: 0.49989, x-valid: 0.45895, x-test: 0.49644, Train errs: 60, Valid errs: 19, Test errs: 29
# Iter:  380, x-train: 0.42998, x-valid: 0.45441, x-test: 0.49660, Train errs: 59, Valid errs: 21, Test errs: 28
# Iter:  400, x-train: 0.43418, x-valid: 0.45939, x-test: 0.48920, Train errs: 61, Valid errs: 21, Test errs: 26
# Iter:  420, x-train: 0.47220, x-valid: 0.45005, x-test: 0.50235, Train errs: 54, Valid errs: 22, Test errs: 29
# Iter:  440, x-train: 0.47164, x-valid: 0.45848, x-test: 0.50226, Train errs: 59, Valid errs: 29, Test errs: 27
# Iter:  460, x-train: 0.47251, x-valid: 0.46098, x-test: 0.50178, Train errs: 57, Valid errs: 23, Test errs: 28
# Iter:  480, x-train: 0.47733, x-valid: 0.45977, x-test: 0.50429, Train errs: 61, Valid errs: 25, Test errs: 29
# Iter:  500, x-train: 0.43016, x-valid: 0.46731, x-test: 0.50734, Train errs: 54, Valid errs: 26, Test errs: 29
# Iter:  520, x-train: 0.43294, x-valid: 0.42387, x-test: 0.49309, Train errs: 53, Valid errs: 24, Test errs: 31
# Iter:  540, x-train: 0.41841, x-valid: 0.43849, x-test: 0.49839, Train errs: 42, Valid errs: 25, Test errs: 30
# Iter:  560, x-train: 0.44821, x-valid: 0.43946, x-test: 0.50387, Train errs: 49, Valid errs: 24, Test errs: 30
# Iter:  580, x-train: 0.45660, x-valid: 0.44242, x-test: 0.51628, Train errs: 54, Valid errs: 26, Test errs: 27
# Iter:  600, x-train: 0.48360, x-valid: 0.44316, x-test: 0.51539, Train errs: 59, Valid errs: 26, Test errs: 29
# Iter:  620, x-train: 0.44733, x-valid: 0.52307, x-test: 0.50555, Train errs: 58, Valid errs: 27, Test errs: 31
# Iter:  640, x-train: 0.43718, x-valid: 0.52672, x-test: 0.50650, Train errs: 59, Valid errs: 27, Test errs: 29
# Iter:  660, x-train: 0.41035, x-valid: 0.53605, x-test: 0.50743, Train errs: 45, Valid errs: 27, Test errs: 27
# Iter:  680, x-train: 0.45688, x-valid: 0.54522, x-test: 0.52236, Train errs: 52, Valid errs: 30, Test errs: 30
# Iter:  700, x-train: 0.44901, x-valid: 0.53765, x-test: 0.51877, Train errs: 59, Valid errs: 27, Test errs: 30
# Iter:  720, x-train: 0.46171, x-valid: 0.43146, x-test: 0.50317, Train errs: 54, Valid errs: 23, Test errs: 26
# Iter:  740, x-train: 0.47189, x-valid: 0.44138, x-test: 0.49570, Train errs: 64, Valid errs: 23, Test errs: 28
# Iter:  760, x-train: 0.42742, x-valid: 0.44585, x-test: 0.49614, Train errs: 54, Valid errs: 23, Test errs: 27
# Iter:  780, x-train: 0.42763, x-valid: 0.44378, x-test: 0.49001, Train errs: 52, Valid errs: 24, Test errs: 26
# Iter:  800, x-train: 0.41984, x-valid: 0.44695, x-test: 0.49712, Train errs: 46, Valid errs: 26, Test errs: 26
# Iter:  820, x-train: 0.48433, x-valid: 0.45347, x-test: 0.51347, Train errs: 54, Valid errs: 19, Test errs: 30
# Iter:  840, x-train: 0.45987, x-valid: 0.45752, x-test: 0.51373, Train errs: 55, Valid errs: 19, Test errs: 29
# Iter:  860, x-train: 0.46827, x-valid: 0.45566, x-test: 0.50005, Train errs: 62, Valid errs: 20, Test errs: 27
# Iter:  880, x-train: 0.43422, x-valid: 0.45773, x-test: 0.50703, Train errs: 57, Valid errs: 21, Test errs: 28
# Iter:  900, x-train: 0.43211, x-valid: 0.46932, x-test: 0.51232, Train errs: 61, Valid errs: 22, Test errs: 29
# Iter:  920, x-train: 0.40616, x-valid: 0.41580, x-test: 0.50857, Train errs: 48, Valid errs: 20, Test errs: 28
# Iter:  940, x-train: 0.45235, x-valid: 0.42250, x-test: 0.51073, Train errs: 50, Valid errs: 19, Test errs: 28
# Iter:  960, x-train: 0.44237, x-valid: 0.42716, x-test: 0.51297, Train errs: 57, Valid errs: 20, Test errs: 29
# Iter:  980, x-train: 0.45368, x-valid: 0.42023, x-test: 0.51089, Train errs: 54, Valid errs: 17, Test errs: 32
# Iter: 1000, x-train: 0.45881, x-valid: 0.42704, x-test: 0.50730, Train errs: 60, Valid errs: 20, Test errs: 30

# %%
# plot training curve for classification accuracy vs number of epochs
plt.plot(train_accuracies, 'b-', label='training')
plt.plot(valid_accuracies, 'r-', label='validation')
plt.plot(test_accuracies, 'g-', label='test')
plt.title('Classification Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

# %%
# plot training curve for classification errors vs number of epochs
plt.plot(train_errors, 'b-', label='training')
plt.plot(valid_errors, 'r-', label='validation')
plt.plot(test_errors, 'g-', label='test')
plt.title('Classification Error vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Errors')
plt.legend()

# %%
# plot training and validation for cross-entropy loss vs number of epochs
plt.plot(train_xentropy_losses, 'b-', label='training')
plt.plot(valid_xentropy_losses, 'r-', label='validation')
plt.plot(test_xentropy_losses, 'g-', label='test')
plt.title('Cross-entropy Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
